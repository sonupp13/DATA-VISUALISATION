# %% [markdown]
# <a href="https://colab.research.google.com/github/sonupp13/DATA-VISUALISATION/blob/main/Matplotlib%20module/DS_MATPLOTLIB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x= range(1,6)
y= range(1,6)
plt.plot(x,y,color="red")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title('simple line plot')
plt.show()

# %%
import matplotlib.pyplot as plt
x= range(1,8)
y= range(1,8)
plt.scatter(x,y, color="b",marker="x",s=100)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("scatter plot")
# Out:
# Text(0.5, 1.0, 'scatter plot')

# %%
import matplotlib.pyplot as plt
categories = ['Category A', 'Category B', 'Category C']
values = [10, 20, 15]
plt.bar(categories,values,color="g")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000)  # Generating random data
plt.hist(data,color='orange',bins=10)
# Out:
# (array([  1.,   4.,  29.,  78., 186., 268., 232., 137.,  49.,  16.]),
#  array([-4.00158866, -3.30197659, -2.60236453, -1.90275247, -1.2031404 ,
#         -0.50352834,  0.19608373,  0.89569579,  1.59530786,  2.29491992,
#          2.99453199]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt

# Predefined data
data = [1 , 2 , 2, 3,  3,  3,  4 ,  4,  5,  6  ,6 , 6]
# Creating a histogram
plt.hist(data,color='skyblue', edgecolor='black' , bins=6 ) #default bin = 10
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of Predefined Data')
plt.show()

# %%
import matplotlib.pyplot as plt

sizes = [70,30]
label = ['Category A', 'Category B']

plt.pie(sizes, labels=label , autopct='%1.1f%%')
plt.title('Pie Chart')
# Out:
# Text(0.5, 1.0, 'Pie Chart')

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/drive/MyDrive/titanic (1).csv")
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
s=df["Sex"].value_counts()
plt.bar(s.index,s.values)
plt.xlabel('Passenger Class')
plt.ylabel('Number of Passengers')
plt.title('Passenger Count by Class')
plt.show()

# %%
age=df['Age'].dropna()
plt.hist(age,bins=20, color='m', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Passenger Age Distribution')
plt.show()

# %%
s= df[['Age','Fare']].dropna()
age=s['Age']
fare=s['Fare']
plt.scatter(age,fare, color='green', marker='x')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Age vs Fare Paid')
plt.show()

# %%
df2=df.groupby(['Pclass','Sex']).size().unstack()
df2
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
import matplotlib.pyplot as plt
import pandas as pd
classcount=df['Sex'].value_counts()
classcount
plt.pie(classcount.values,labels=classcount.index,autopct='%1.1f%%')
plt.title('pie chart')
# Out:
# Text(0.5, 1.0, 'pie chart')

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000)  # Generating random data
plt.hist(data,color='orange' ,bins=5)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %% [markdown]
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.
#
# Some of the major Pros of Matplotlib are:
#
# Generally easy to get started for simple plots
# Support for custom labels and texts
# Great control of every element in a figure
# High-quality output in many formats
# Very customizable in **general** bold text

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(1,10)
y=np.arange(1,10)
plt.scatter(x,y,c='y')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig('Test.png')

# %%
y=x*x
y
plt.plot(x,y,'g*',linestyle='dotted',linewidth=2,markersize=10)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2d Diagram')
# Out:
# Text(0.5, 1.0, '2d Diagram')

# %%
plt.subplot(2,2,1)
plt.scatter(x,y)

plt.subplot(2,2,2)
plt.plot(x,y)

plt.subplot(2,2,3)
plt.plot(x,y,'r*')

plt.subplot(2,2,4)
plt.plot(x,y,'go')

# %%
x=np.arange(1,11)
y= 3*x + 5
plt.plot(x,y)
plt.title("Matplotlib demo")
plt.xlabel("x axis caption")
plt.ylabel("y axis caption")
# Out:
# Text(0, 0.5, 'y axis caption')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x=np.arange( 0, 4*np.pi,0.1)
y=np.sin(x)
plt.plot(x,y)

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0, 5*np.pi,0.1)
ysin=np.sin(x)
ycos=np.cos(x)
plt.subplot(2, 1, 1)
plt.plot(x, ysin,'r--')
plt.title('Sine')
plt.subplot(2, 1, 2)
plt.plot(x, ycos,'g--')
plt.title('Cosine')
plt.show()

# %%
x = [2,8,10]
y = [11,16,9]

x2 = [3,9,11]
y2 = [6,15,7]
plt.bar(x, y,color='red')
plt.bar(x2, y2, color = 'g')
plt.title('Bar graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %%
z

# %% [markdown]
# Box Plot using ***Matplotlib***

# %%
data = [68, 75, 78, 79, 81, 82, 85, 87, 88, 90, 92 ]

print(np.median(data))
plt.boxplot(data)
plt.xlabel('Data')
plt.ylabel('Value')
plt.title('Boxplot')
# Out:
# 82.0
# Text(0.5, 1.0, 'Boxplot')

# %% [markdown]
# pie chart

# %%
labels= 'sonu','somu','soku','sodu'
sizes= [200,300,350,150]
colors=['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explod = (0.3, 0, 0, 0)
plt.pie(sizes,labels=labels,colors=colors,explode=explod,autopct='%1.1f%%', shadow=True)
plt.axis('equal')
plt.show()
